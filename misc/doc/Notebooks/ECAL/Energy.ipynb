# %%
# %pylab inline
# %run ../utils.py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = get_data()

# %%
from matplotlib.colors import LogNorm
import seaborn as s
s.set(rc={'image.cmap': "jet"})
config_plots(rcParams)

# %% [markdown]
# #1 ECAL Energy

# %%
data['EnergyE'][data['EnergyE'] > 0].hist(bins=np.linspace(0,2,100))

# %% [markdown]
# # 2. Energy by the MIP layer

# %%
idx = (data['EnergyE']>0)
def getdedx(nlayer):
    return data['EnergyE'][idx & (data['nlayMip'] == layer)]
for layer in range(1,7):
    getdedx(layer).hist(bins=np.linspace(0,5,100), histtype='step', lw=2, label='ECAlLayer'+str(layer))
legend()
