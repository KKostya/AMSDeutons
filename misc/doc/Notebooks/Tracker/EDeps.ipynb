# %%
# %pylab inline
# %run ../utils.py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = get_data()

# %%
from matplotlib.colors import LogNorm
import seaborn as s
s.set(rc={'image.cmap': "jet"})
config_plots(rcParams)

# %%
figsize(15,3)
data['Rcutoff'][data['Rcutoff']>0].hist(bins=np.linspace(0,29,100), cumulative=True, normed=True)
figsize(8,6)

# %%
figsize(7,7)
sel = lambda s: [ c for c in data.columns 
    if c.startswith(s) and  c[-1] in ["0","8"]]

etrack   = data[sel("EDepTrack")].sum(axis=1)
etracker = data[sel("EDepLayer")].sum(axis=1)
idx = (etrack > 0) & (etracker> 0)
scatter(etrack[idx], etracker[idx]-etrack[idx],c='k',marker='.',lw=0)
xlim(0.01,100); xlabel("EDepTrack");
ylim(0.01,100); ylabel("EDepLayer - EDepTrack");
xscale('log')
yscale('log')
