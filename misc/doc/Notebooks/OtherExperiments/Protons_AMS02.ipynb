 175& $-$ &  192 & (8.212 &   0.023 &   0.017 &   0.087 &   0.079 &   0.059 &   0.133)&$\times 10^{-3}$ \\
 192& $-$ &  211 & (6.299 &   0.019 &   0.014 &   0.068 &   0.062 &   0.047 &   0.104)&$\times 10^{-3}$ \\
 211& $-$ &  233 & (4.793 &   0.015 &   0.011 &   0.053 &   0.049 &   0.039 &   0.083)&$\times 10^{-3}$ \\
 233& $-$ &  259 & (3.605 &   0.012 &   0.009 &   0.040 &   0.039 &   0.031 &   0.065)&$\times 10^{-3}$ \\
 259& $-$ &  291 & (2.647 &   0.009 &   0.007 &   0.030 &   0.029 &   0.024 &   0.049)&$\times 10^{-3}$ \\
 291& $-$ &  330 & (1.884 &   0.007 &   0.006 &   0.022 &   0.022 &   0.019 &   0.037)&$\times 10^{-3}$ \\
 330& $-$ &  379 & (1.288 &   0.005 &   0.004 &   0.016 &   0.016 &   0.015 &   0.027)&$\times 10^{-3}$ \\
 379& $-$ &  441 & (8.695 &   0.038 &   0.034 &   0.110 &   0.112 &   0.111 &   0.195)&$\times 10^{-4}$ \\
 441& $-$ &  525 & (5.545 &   0.026 &   0.025 &   0.073 &   0.078 &   0.078 &   0.135)&$\times 10^{-4}$ \\
 525& $-$ &  643 & (3.357 &   0.017 &   0.018 &   0.047 &   0.052 &   0.057 &   0.092)&$\times 10^{-4}$ \\
 643& $-$ &  822 & (1.860 &   0.010 &   0.012 &   0.028 &   0.032 &   0.040 &   0.060)&$\times 10^{-4}$ \\
 822& $-$ & 1130 & (8.571 &   0.053 &   0.071 &   0.139 &   0.192 &   0.254 &   0.355)&$\times 10^{-5}$ \\
1130& $-$ & 1800 & (2.933 &   0.021 &   0.035 &   0.055 &   0.092 &   0.130 &   0.173)&$\times 10^{-5}$ \\
"""

# %%
protons = pd.DataFrame(l.split('&') for l in protonsAMS02.splitlines()[1:])
protons = protons.iloc[:,[0,2,3,4,5,6,7,8,9,10]]
protons.columns = [
    "Rmin", "Rmax", "Phi", 
    "stat","trig","acc","unf","scale",
    "Total", "Exp"
]

protons["Phi"]   = protons["Phi"]  .map(lambda x: float(x.split('(')[1]))
protons["Total"] = protons["Total"].map(lambda x: float(x.split(')')[0]))
protons['Exp']   = protons['Exp'].map(lambda x: x.split('{')[1].split('}')[0])

protons = protons.astype(float).set_index(["Rmin","Rmax"])
protons = protons.mul(protons['Exp'].map(lambda x: 10**x).values, axis=0).iloc[:,:-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eb95a441d593> in <module>()
# ----> 1 protons = pd.DataFrame(l.split('&') for l in protonsAMS02.splitlines()[1:])
#       2 protons = protons.iloc[:,[0,2,3,4,5,6,7,8,9,10]]
#       3 protons.columns = [
#       4     "Rmin", "Rmax", "Phi",
#       5     "stat","trig","acc","unf","scale",
#
# NameError: name 'pd' is not defined
