# %%
# %pylab inline
import ROOT
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tfile = ROOT.TFile("../test.root")
tree = tfile.Get("data")

# %%
def tree_to_frame(tree):
    
    N = tree.GetEntries()
    varNames = [b.GetName() for b in tree.GetListOfBranches() if  b.ClassName() == "TBranch"]
    arrNames = [b.GetName() for b in tree.GetListOfBranches() if  b.ClassName() == "TBranchElement"]
    
    vs = { v:np.zeros(N) for v in varNames }
    for j in xrange(N):
        tree.GetEntry(j)
        for v in varNames: vs[v][j] = getattr(tree,v)
        for v in arrNames: 
            for i in xrange(getattr(tree,v).size()):
                name = "{0}[{1}]".format(v,i)
                if name not in vs: vs[name] = np.zeros(N)
                vs[name][j] = getattr(tree,v)[i]
                
    return pd.DataFrame(vs)

# %%
data = tree_to_frame(tree)

# %%
data = data.set_index(['Run', 'Event'])

# %%
data.plot(kind='scatter', x='R', y='BetaTOF', marker='.', lw=0)
xlim(0,20)
ylim(0.4,1.0)
# Out:
# (0.4, 1.0)

# %%
data.columns
# Out:
# Index([u'BetaCorr', u'BetaRICH', u'BetaTOF', u'Chisquare', u'EdepTOF[0]', u'EdepTOF[1]', u'EdepTOF[2]', u'EdepTOF[3]', u'EdepTRD', u'EdepTrack', u'Mass', u'NTRDclusters', u'NTofClusters', u'NTofClustersUsed', u'NTrackHits', u'R', u'R_[0]', u'R_[1]', u'R_[2]', u'R_[3]', u'R_[4]', u'R_[5]', u'Rdown', u'ResiduiX[0]', u'ResiduiX[1]', u'ResiduiX[2]', u'ResiduiX[3]', u'ResiduiX[4]', u'ResiduiX[5]', u'ResiduiX[6]', u'ResiduiY[0]', u'ResiduiY[1]', u'ResiduiY[2]', u'ResiduiY[3]', u'ResiduiY[4]', u'ResiduiY[5]', u'ResiduiY[6]', u'Rup', u'UTime', u'chiq[0]', u'chiq[1]', u'chiq[2]', u'chiq[3]', u'chiq[4]', u'chiq[5]', u'unusedLayers'], dtype='object')
