# %%
# %pylab inline
import ROOT
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pyAmsUtils import tree_to_frame

# %%
#tfile = ROOT.TFile("../test.root")
tfiles = [ROOT.TFile("/data/deuteronMC.ntuple{0}.root".format(i)) for i in range(1,4)]

# %%
data = pd.concat([tree_to_frame(tfile.Get("data")) for tfile in tfiles])

# %%
data = data.set_index(['Run','Event'])

# %%
figsize(15,10)
ax = gca()
data.plot(kind='Scatter', x='R', y='BetaTOF',  marker='.', lw=0 , ax=ax)
data.plot(kind='Scatter', x='R', y='BetaRICH', marker=',', s=20, c='r' ,lw=0, ax=ax)
xlim(0,20)
ylim(0.5,1)
# Out:
# (0.5, 1)

# %%
figsize(10,10)
data.plot(kind='Scatter', x='GenMomentum', y='R',  marker='.', lw=0)
xlim(0,10)
ylim(0,10)
# Out:
# (0, 10)

# %%
sum(data['BetaRICH']> 0)
# Out:
# 298
